# %% [markdown]
# ### Python Conditions and If statements
#
# allows for conditional execution of a statement or group of statements based on the value of an expression.
#
# Python supports the usual logical conditions from mathematics:
#
# * Equals: a == b
#
# * Not Equals: a != b
#
# * Less than: a < b
#
# * Less than or equal to: a <= b
#
# * Greater than: a > b
#
# * Greater than or equal to: a >= b

# %%
a = 33
b = 200
if b>a :
    print("b is greater than a")
# Out:
# b is greater than a

# %%
# note - indentation should be in mind

a = 33
b = 200

if b>a:
print("b is greater than a ") 

# this wil give us an error because of wrong 
# indentation
# Out:
#   Input In [2]
#     print("b is greater than a ")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ### Else
# The else keyword catches anything which isn't caught by the preceding conditions.

# %%
a = 200
b = 33
if b>a:
    print("b is greater than a")
elif a == b :
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 200
b = 33

if b >a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %% [markdown]
# ### Short Hand If
# If you have only one statement to execute, you can put it on the same line as the if statement.

# %%
a = 200
b = 33
if a>b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ### Short Hand If ... Else
# If you have only one statement to execute, one for if, and one for else, you can put it all on the same line:

# %%
a = 2
b = 330

print("A") if a>b else print("B")
# Out:
# B

# %% [markdown]
# ### This technique is known as Ternary Operators, or Conditional Expressions

# %%
###One line if else statement, with 3 conditions:

a = 330
b = 330

print("A") if a>b else print("=") if a == b else print("B")
# Out:
# =

# %%
### One line if else statement, with 3 conditions:

a = 330
b = 410

print("A") if a>b else print("=") if a == b else print("B")
# Out:
# B

# %%
list1 = [1,2,3,'hello']
list2 = ['a', 'b', 'c']
print("Yes") if 1 in list1 else print("No") if 1 not in list1 else print("we don't know")
# Out:
# Yes

# %%
list1 = [1,2,3,'hello']
list2 = ['a', 'b', 'c']
print("Yes") if 5 in list1 else print("No") if 'a' not in list2 else print("we don't know")
# Out:
# we don't know

# %% [markdown]
# ### And
# The and keyword is a logical operator, and is used to combine conditional statements:
#
# Test if a is greater than b, AND if c is greater than a:

# %%
a = 200
b = 33
c = 500

if a>b and c>a :
    print("Both the condtions are True")
# Out:
# Both the condtions are True

# %% [markdown]
# ### Or
# The or keyword is a logical operator, and is used to combine conditional statements:
#
# Example
# Test if a is greater than b, OR if a is greater than c:

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
    print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# ### Nested If
# You can have if statements inside if statements, this is called nested if statements.

# %%
x = 41

if x>10:
    print("Above ten,")
    if x>20:
        print("and also above 20!")
    else:
        print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
x = 41

if x>10:
    print("Above ten,")
    if x>44:
        print("and also above 44!")
    else:
        print("but not above 44.")
# Out:
# Above ten,
# but not above 44.

# %% [markdown]
# ### The pass Statement
#
# if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.

# %%
a = 33
b = 200

if b>a:
    pass

# %% [markdown]
# Thank You 👍
